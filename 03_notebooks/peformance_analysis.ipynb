# %% [markdown]
# # Vendor Performance Analysis
# This notebook analyzes vendor performace using the data from the gold.vendor_performance table in PostgreSql.

# %% [markdown]
#  Configure Project Path
#
# this step add the source directory (02_src) to the Python path so custom module can be imported inside the notebook.

# %%
import sys
from pathlib import Path
sys.path.append(str(Path().resolve().parent/"02_src"))

# %%
from db import get_engine
engine = get_engine()
# Out:
# Loading environment variables from: C:\Users\nabap\Vendor_Performance_Analysis\config\db_config.env
# File Exists: True

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")
from scipy.stats import ttest_ind
from scipy.stats import stats

# %%
df = pd.read_sql("select * from gold.vendor_performance", engine)
df.head()
# Out:
#    vendor_number               vendor_name  brand              description  \
# 0           1128         BROWN-FORMAN CORP   1233  Jack Daniels No 7 Black
# 1           4425     MARTIGNETTI COMPANIES   3405    Tito's Handmade Vodka
# 2          17035         PERNOD RICARD USA   8068         Absolut 80 Proof
# 3           3960  DIAGEO NORTH AMERICA INC   4261   Capt Morgan Spiced Rum
# 4           3960  DIAGEO NORTH AMERICA INC   3545          Ketel One Vodka
#
#    actual_price  avg_purchase_price  total_purchase_qty  total_sales_qty  \
# 0         36.99               26.27              145080         142049.0
# 1         28.99               23.19              164038         160247.0
# 2         24.99               18.24              187407         187140.0
# 3         22.99               16.17              201682         200412.0
# 4         29.99               21.89              138109         135838.0
#
#    total_purchase_amount  total_sales_amount  excise_tax  freight_cost  \
# 0             3811251.60          5101919.51   260999.20      19325.15
# 1             3804041.22          4819073.49   294438.66      19787.63
# 2             3418303.68          4538120.60   343854.07      17539.25
# 3             3261197.94          4475972.88   368242.80      16448.90
# 4             3023206.01          4223107.62   249587.83      15248.51
#
#    price_discount  gross_profit  profit_margin  sell_through_rate
# 0           10.72    1290667.91          25.30              97.91
# 1            5.80    1015032.27          21.06              97.69
# 2            6.75    1119816.92          24.68              99.86
# 3            6.82    1214774.94          27.14              99.37
# 4            8.10    1199901.61          28.41              98.36

# %%
df.shape
# Out:
# (10692, 16)

# %%
df.describe().T
# Out:
#                          count          mean            std       min  \
# vendor_number          10692.0  10650.649458   18753.519148      2.00
# brand                  10692.0  18039.228769   12662.187074     58.00
# actual_price           10689.0     35.653537     148.265650      0.99
# avg_purchase_price     10692.0     24.385303     109.269375      0.36
# total_purchase_qty     10692.0   3140.886831   11095.086769      1.00
# total_sales_qty        10514.0   3129.573521   11037.803031      1.00
# total_purchase_amount  10692.0  30106.693372  123067.799627      0.71
# total_sales_amount     10514.0  42954.173834  168977.755843      1.98
# excise_tax             10514.0   1804.255062   11065.658551      0.06
# freight_cost           10692.0    153.430075     626.756009      0.00
# price_discount         10689.0     11.261496      40.130012      0.20
# gross_profit           10514.0  12364.618776   46576.616345 -52002.78
# profit_margin          10514.0    -15.885263     447.289858 -23730.64
# sell_through_rate      10514.0    173.567585     606.708298      0.28
#
#                              25%        50%         75%         max
# vendor_number          3951.0000   7153.000   9552.0000   201359.00
# brand                  5793.5000  18761.500  25514.2500    90631.00
# actual_price             10.9900     15.990     28.9900     7499.99
# avg_purchase_price        6.8400     10.455     19.4825     5681.81
# total_purchase_qty       36.0000    262.000   1975.7500   337660.00
# total_sales_qty          36.0000    280.000   1985.0000   334939.00
# total_purchase_amount   453.4575   3655.465  20738.2450  3811251.60
# total_sales_amount      809.8200   5599.700  29524.2500  5101919.51
# excise_tax                5.3825     50.425    436.7300   368242.80
# freight_cost              2.3100     18.740    106.2425    19787.63
# price_discount            3.5400      5.410      9.2600     1818.18
# gross_profit             66.9750   1496.490   8970.0400  1290667.91
# profit_margin            15.3550     30.780     40.2100       99.72
# sell_through_rate        82.9800     98.340    104.2200    27450.00

# %%
df.isnull().sum()
# Out:
# vendor_number              0
# vendor_name                0
# brand                      0
# description                0
# actual_price               3
# avg_purchase_price         0
# total_purchase_qty         0
# total_sales_qty          178
# total_purchase_amount      0
# total_sales_amount       178
# excise_tax               178
# freight_cost               0
# price_discount             3
# gross_profit             178
# profit_margin            178
# sell_through_rate        178
# dtype: int64

# %% [markdown]
# # Missing value summary
#
# * the dataset is largely complete with very few missing values.
# * actual_price and price_discount contain 3 missing records each.
# * sales related variables contain 178 missing values, likely represents vendors with no recorded sales trasaction.
# * since these values correspond to the absence of sales activity, they were replaces with 0 to maintain consistency.

# %%
df.fillna(0, inplace=True)
# Out:
#        vendor_number               vendor_name  brand  \
# 0               1128         BROWN-FORMAN CORP   1233
# 1               4425     MARTIGNETTI COMPANIES   3405
# 2              17035         PERNOD RICARD USA   8068
# 3               3960  DIAGEO NORTH AMERICA INC   4261
# 4               3960  DIAGEO NORTH AMERICA INC   3545
# ...              ...                       ...    ...
# 10687           9815            WINE GROUP INC   8527
# 10688           8004            SAZERAC CO INC   5683
# 10689           3924  HEAVEN HILL DISTILLERIES   9123
# 10690           3960  DIAGEO NORTH AMERICA INC   6127
# 10691           7245      PROXIMO SPIRITS INC.   3065
#
#                        description  actual_price  avg_purchase_price  \
# 0          Jack Daniels No 7 Black         36.99               26.27
# 1            Tito's Handmade Vodka         28.99               23.19
# 2                 Absolut 80 Proof         24.99               18.24
# 3           Capt Morgan Spiced Rum         22.99               16.17
# 4                  Ketel One Vodka         29.99               21.89
# ...                            ...           ...                 ...
# 10687  Concannon Glen Ellen Wh Zin          4.99                1.32
# 10688  Dr McGillicuddy's Apple Pie          0.00                0.39
# 10689              Deep Eddy Vodka          0.99                0.74
# 10690  The Club Strawbry Margarita          1.99                1.47
# 10691     Three Olives Grape Vodka          0.99                0.71
#
#        total_purchase_qty  total_sales_qty  total_purchase_amount  \
# 0                  145080         142049.0             3811251.60
# 1                  164038         160247.0             3804041.22
# 2                  187407         187140.0             3418303.68
# 3                  201682         200412.0             3261197.94
# 4                  138109         135838.0             3023206.01
# ...                   ...              ...                    ...
# 10687                   2              5.0                   2.64
# 10688                   6            134.0                   2.34
# 10689                   2              2.0                   1.48
# 10690                   1             72.0                   1.47
# 10691                   1             86.0                   0.71
#
#        total_sales_amount  excise_tax  freight_cost  price_discount  \
# 0              5101919.51   260999.20      19325.15           10.72
# 1              4819073.49   294438.66      19787.63            5.80
# 2              4538120.60   343854.07      17539.25            6.75
# 3              4475972.88   368242.80      16448.90            6.82
# 4              4223107.62   249587.83      15248.51            8.10
# ...                   ...         ...           ...             ...
# 10687               15.95        0.55          0.01            3.67
# 10688               65.66        7.04          0.01            0.00
# 10689                1.98        0.10          0.01            0.25
# 10690              143.28       15.12          0.01            0.52
# 10691               85.14        4.46          0.00            0.28
#
#        gross_profit  profit_margin  sell_through_rate
# 0        1290667.91          25.30              97.91
# 1        1015032.27          21.06              97.69
# 2        1119816.92          24.68              99.86
# 3        1214774.94          27.14              99.37
# 4        1199901.61          28.41              98.36
# ...             ...            ...                ...
# 10687         13.31          83.45             250.00
# 10688         63.32          96.44            2233.33
# 10689          0.50          25.25             100.00
# 10690        141.81          98.97            7200.00
# 10691         84.43          99.17            8600.00
#
# [10692 rows x 16 columns]

# %%
df.columns
# Out:
# Index(['vendor_number', 'vendor_name', 'brand', 'description', 'actual_price',
#        'avg_purchase_price', 'total_purchase_qty', 'total_sales_qty',
#        'total_purchase_amount', 'total_sales_amount', 'excise_tax',
#        'freight_cost', 'price_discount', 'gross_profit', 'profit_margin',
#        'sell_through_rate'],
#       dtype='str')

# %% [markdown]
# # Understand the distribution of numerical and categorical columns
#
# These plots help identify the data spread, skewness, presence of potential ouliers, providing an intial understanding of how these variables are distributed.

# %%
import math
# price related columns
price_cols = ['actual_price','avg_purchase_price','total_purchase_qty','total_purchase_amount']

n_cols = 3
n_rows = math.ceil(len(price_cols)/n_cols)

plt.figure(figsize=(10,2*n_rows))
for i, col in enumerate(price_cols):
    plt.subplot(n_rows,n_cols,i+1)
    sns.histplot(df[col], kde=True, bins=30)
   # plt.title(col, fontsize=10)
plt.tight_layout(pad=3)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sales_cols = ['total_sales_qty','total_sales_amount','excise_tax','freight_cost']

n_cols = 3
n_rows = math.ceil(len(sales_cols)/n_cols)

plt.figure(figsize=(10,2*n_rows))
for i, col in enumerate(sales_cols):
    plt.subplot(n_rows,n_cols,i+1)
    sns.histplot(df[col], kde=True, bins=30)
   # plt.title(col, fontsize=10)
plt.tight_layout(pad=3)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
profit_cols = ['profit_margin','gross_profit','price_discount']

n_cols = 3
n_rows = math.ceil(len(profit_cols)/n_cols)

plt.figure(figsize=(10,3*n_rows))
for i, col in enumerate(profit_cols):
    plt.subplot(n_rows,n_cols,i+1)
    sns.histplot(df[col], kde=True, bins=30)
   # plt.title(col, fontsize=10)
plt.tight_layout(pad=3)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
numeric_cols=df.select_dtypes(include=np.number).columns
n_cols = 4
n_rows = math.ceil(len(numeric_cols)/n_cols)

plt.figure(figsize=(12,3*n_rows))
for i, col in enumerate(numeric_cols):
    plt.subplot(n_rows,n_cols,i+1)
    sns.boxenplot(y=df[col])
   # plt.title(col, fontsize=10)
plt.tight_layout(pad=3)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # outliers detection
#
# * boxplots were used to identify outliers in numerical variables.
# * several variables show extreme values, indicationg a small number of vendors with very large transactions.
# * detecting outliers is important because they can skew analysis result but here these records are important as they represent transactions.

# %%
category_cols = ['vendor_name','description']
n_cols = 3
n_rows = math.ceil(len(category_cols)/n_cols)

plt.figure(figsize=(16,4*n_rows))
for i, col in enumerate(category_cols):
    plt.subplot(n_rows,n_cols,i+1)
    sns.countplot(y=df[col], order=df[col].value_counts().index[:10], palette='viridis')
    plt.title(f'Countplot of {col}', fontsize=10)
plt.tight_layout(pad=3)
plt.show()

# %%
numeric_cols=df.select_dtypes(include=np.number).drop(columns=['vendor_number','brand']).columns
plt.figure(figsize=(12,6))
correlation_matrix = df[numeric_cols].corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Correlation Matrix of Numeric Features', fontsize=12)
plt.show()

# %% [markdown]
# ### correlation analysis
#
# 1. a correlation heatmap was used to examine relationship between numerical variables.
# 2. strong positive correlation are observed between purchase amount, sales amount, freight cost and gross profit.
# 3. profit margin and sell-through-rate have weak correlations with most variables, indicating they are influence by multiple factors.

# %% [markdown]
# ### Q. Identify the brands that needs promotional or pricing adjustment which exhibit lower sales but higher profit margin ?

# %%
'''brand performance analysis'''
brand_performance = df.groupby('description').agg({'total_sales_amount':'sum', 'profit_margin':'mean'}).reset_index()

'''thresh set for low sales and high profit margin'''
low_sales_threshold = df['total_sales_amount'].quantile(0.15)
high_profit_threshold = df['profit_margin'].quantile(0.85)

'''identify target brands'''
target_brands = brand_performance[
    (brand_performance['total_sales_amount'] <= low_sales_threshold) &
    (brand_performance['profit_margin'] >= high_profit_threshold)
]
print("Target Brands for Improvement:")
display(target_brands.sort_values(by='total_sales_amount', ascending=False))
# Out:
# Target Brands for Improvement:
#                        description  total_sales_amount  profit_margin
# 6249      Morande Edicion Limitada              284.81          79.35
# 3980              Gifft Chardonnay              279.80          94.25
# 5736   Mad Dogs & Englishmen Jumil              279.80          97.67
# 9229         Vigne A Porrona Rosso              272.79          96.83
# 8939  Tommasi Poggio Tufo Cab Svgn              269.73          74.79
# ...                            ...                 ...            ...
# 7818  Sauza Sprklg Wild Berry Marg               27.96          82.15
# 2677             Crown Royal Apple               27.86          89.81
# 2537   Concannon Glen Ellen Wh Zin               15.95          83.45
# 2896             Debauchery Pnt Nr               11.58          65.98
# 7777    Santa Rita Organic Svgn Bl                9.99          66.47
#
# [110 rows x 3 columns]

# %% [markdown]
# ### Brands requiring promotional campaigns
#
# 1. brands with low total sales but high profit margins were identified using percentile tresholds.
# 2. there are more than 100 brands genrate good margins but low sales volume, suggesting limited market reach or pricing barriers.
# 3. such brands may benefit from promotional campaignns, pricing adjustment to increase sales while maintaining profitability.

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(data=brand_performance, x='total_sales_amount', y='profit_margin', color='blue', label='Brands', alpha=0.2)
sns.scatterplot(data=target_brands, x='total_sales_amount', y='profit_margin', color='red', label='Target Brands')
plt.axhline(y=high_profit_threshold, color='black', linestyle='--', label='High Profit Threshold')
plt.axvline(x=low_sales_threshold, color='black', linestyle='--', label='Low Sales Threshold')
plt.xlabel('Total Sales Amount')
plt.ylabel('Profit Margin')
plt.title('Target Brands for promotion and pricing adjustment')
plt.legend()
plt.grid(True)
plt.xscale('log')
plt.show()

# %%
import plotly.express as px
import plotly.io as pio

pio.renderers.default = "vscode"

non_target = brand_performance[
    ~brand_performance['description'].isin(target_brands['description'])
]

fig = px.scatter(
    non_target,
    x='total_sales_amount',
    y='profit_margin',
    hover_name='description',
    title='Target Brands for Promotion and Pricing Adjustment',
    color_discrete_sequence=['blue']
)

# highlight target brands
fig.add_scatter(
    x=target_brands['total_sales_amount'],
    y=target_brands['profit_margin'],
    mode='markers',   # removed +text
    marker=dict(color='red', size=12),
    name='Target Brands',
    customdata=target_brands['description'],
    hovertemplate="<b>%{customdata}</b><br>Sales: %{x:,.0f}<br>Profit Margin: %{y:.2f}<extra></extra>"
)

fig.add_hline(y=high_profit_threshold, line_dash="dash", line_color="black")
fig.add_vline(x=low_sales_threshold, line_dash="dash", line_color="black")

fig.update_layout(
    width=1100,
    height=650
)
fig.update_xaxes(type="log")
fig.show()

# %% [markdown]
# ### Q. Which vendor or brand demonstrate the highest sales performance ?

# %%
def format_dollar(x):
    if x >= 1e6:
        return f'${x/1e6:.2f}M'
    elif x >= 1e3:
        return f'${x/1e3:.2f}K'
    else:
        return f'${x:.0f}'

# %%
top_vendors = df.groupby('vendor_name')['total_sales_amount'].sum().nlargest(10)
top_vendors = top_vendors.apply(format_dollar).sort_values(ascending=False)
top_vendors
# Out:
# vendor_name
# DIAGEO NORTH AMERICA INC      $68.74M
# MARTIGNETTI COMPANIES         $40.96M
# PERNOD RICARD USA             $32.28M
# JIM BEAM BRANDS COMPANY       $31.90M
# BACARDI USA INC               $25.01M
# CONSTELLATION BRANDS INC      $24.47M
# E & J GALLO WINERY            $18.55M
# BROWN-FORMAN CORP             $18.48M
# ULTRA BEVERAGE COMPANY LLP    $17.80M
# M S WALKER INC                $15.44M
# Name: total_sales_amount, dtype: str

# %%
top_brands = df.groupby('description')['total_sales_amount'].sum().nlargest(10)
top_brands = top_brands.apply(format_dollar).sort_values(ascending=False)
top_brands
# Out:
# description
# Jack Daniels No 7 Black    $7.96M
# Tito's Handmade Vodka      $7.40M
# Grey Goose Vodka           $7.21M
# Capt Morgan Spiced Rum     $6.36M
# Absolut 80 Proof           $6.24M
# Jameson Irish Whiskey      $5.72M
# Ketel One Vodka            $5.07M
# Baileys Irish Cream        $4.15M
# Kahlua                     $3.60M
# Tanqueray                  $3.46M
# Name: total_sales_amount, dtype: str

# %%
top_vendors = df.groupby('vendor_name')['total_sales_amount'].sum().nlargest(10)

top_brands = df.groupby('description')['total_sales_amount'].sum().nlargest(10)

fig, axes = plt.subplots(1, 2, figsize=(15,6))
# plot for top vendors 
sns.barplot(x=top_vendors.values, y=top_vendors.index.astype(str), color='steelblue', ax=axes[0])
axes[0].set_title('Top 10 Vendors by Sales Amount', fontsize=12)
axes[0].set_xlabel('Total Sales Amount')
axes[0].set_ylabel('Vendor Name')
axes[0].grid(False)
for i, v in enumerate(top_vendors.values):
    axes[0].text(v + (v * 0.02), i, f"${v/1e6:.2f}M", va='center', fontsize=9, ha='left', color='black')

# plot for top brands
sns.barplot(x=top_brands.values, y=top_brands.index.astype(str), color='steelblue', ax=axes[1])
axes[1].set_title('Top 10 Brands by Sales Amount', fontsize=12)         
axes[1].set_xlabel('Total Sales Amount')
axes[1].set_ylabel('Brand Description')
axes[1].grid(False)
for i, v in enumerate(top_brands.values):
    axes[1].text(v + (v * 0.02), i, f"${v/1e6:.2f}M", va='center', fontsize=9, ha='left', color='black')
sns.despine()
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Q. Which vendors contribute the most to the total_purchase_amount ?

# %%
# calculate the purchase contribution of each vendor
vendor_performance = df.groupby('vendor_name').agg({'total_purchase_amount':'sum','gross_profit':'sum','total_sales_amount':'sum'}).reset_index()
vendor_performance['purchase_contribution'] = vendor_performance['total_purchase_amount']/vendor_performance['total_purchase_amount'].sum() * 100
vendor_performance = vendor_performance.round(2).sort_values(by='purchase_contribution', ascending=False).head(10)

# %%
# calculate the sales contribution of each vendor
vendor_performance = df.groupby('vendor_name').agg({'total_purchase_amount':'sum','gross_profit':'sum','total_sales_amount':'sum'}).reset_index()
vendor_performance['sales_contribution'] = vendor_performance['total_sales_amount']/vendor_performance['total_sales_amount'].sum() * 100
vendor_performance = vendor_performance.round(2).sort_values(by='sales_contribution', ascending=False).head(10)

# %%
# format the sales contribution for better readability
top_vendor = vendor_performance.sort_values(by='sales_contribution', ascending=False).head(10)
top_vendor['total_sales_amount'] = top_vendor['total_sales_amount'].apply(format_dollar)
top_vendor['gross_profit'] = top_vendor['gross_profit'].apply(format_dollar)
top_vendor['total_purchase_amount'] = top_vendor['total_purchase_amount'].apply(format_dollar)
top_vendor
# Out:
#                     vendor_name total_purchase_amount gross_profit  \
# 28     DIAGEO NORTH AMERICA INC               $50.96M      $17.78M
# 63        MARTIGNETTI COMPANIES               $27.86M      $13.14M
# 74            PERNOD RICARD USA               $24.12M       $8.16M
# 50      JIM BEAM BRANDS COMPANY               $24.20M       $7.70M
# 8               BACARDI USA INC               $17.62M       $7.38M
# 23     CONSTELLATION BRANDS INC               $15.57M       $8.90M
# 33           E & J GALLO WINERY               $12.29M       $6.27M
# 14            BROWN-FORMAN CORP               $13.53M       $4.95M
# 114  ULTRA BEVERAGE COMPANY LLP               $13.21M       $4.70M
# 59               M S WALKER INC               $10.94M       $4.56M
#
#     total_sales_amount  sales_contribution
# 28             $68.74M               15.22
# 63             $40.96M                9.07
# 74             $32.28M                7.15
# 50             $31.90M                7.06
# 8              $25.01M                5.54
# 23             $24.47M                5.42
# 33             $18.55M                4.11
# 14             $18.48M                4.09
# 114            $17.80M                3.94
# 59             $15.44M                3.42

# %%
# format the purchase contribution for better readability
top_vendor = vendor_performance.sort_values(by='purchase_contribution', ascending=False).head(10)
top_vendor['total_purchase_amount'] = top_vendor['total_purchase_amount'].apply(format_dollar)
top_vendor['gross_profit'] = top_vendor['gross_profit'].apply(format_dollar)
top_vendor['total_sales_amount'] = top_vendor['total_sales_amount'].apply(format_dollar)
top_vendor
# Out:
#                     vendor_name total_purchase_amount gross_profit  \
# 28     DIAGEO NORTH AMERICA INC               $50.96M      $17.78M
# 63        MARTIGNETTI COMPANIES               $27.86M      $13.14M
# 50      JIM BEAM BRANDS COMPANY               $24.20M       $7.70M
# 74            PERNOD RICARD USA               $24.12M       $8.16M
# 8               BACARDI USA INC               $17.62M       $7.38M
# 23     CONSTELLATION BRANDS INC               $15.57M       $8.90M
# 14            BROWN-FORMAN CORP               $13.53M       $4.95M
# 114  ULTRA BEVERAGE COMPANY LLP               $13.21M       $4.70M
# 33           E & J GALLO WINERY               $12.29M       $6.27M
# 59               M S WALKER INC               $10.94M       $4.56M
#
#     total_sales_amount  purchase_contribution
# 28             $68.74M                  15.83
# 63             $40.96M                   8.66
# 50             $31.90M                   7.52
# 74             $32.28M                   7.49
# 8              $25.01M                   5.48
# 23             $24.47M                   4.84
# 14             $18.48M                   4.20
# 114            $17.80M                   4.10
# 33             $18.55M                   3.82
# 59             $15.44M                   3.40

# %%
import matplotlib.pyplot as plt
import numpy as np

top_vendor = vendor_performance.sort_values(by='purchase_contribution', ascending=False).head(10)

# use numeric column
top_vendor['cummulative_contribution'] = top_vendor['purchase_contribution'].cumsum()



fig, ax1 = plt.subplots(figsize=(10,6))

# bars
ax1.bar(
    top_vendor['vendor_name'],
    top_vendor['total_purchase_amount'],
    color="steelblue"
)

ax1.set_ylabel("Purchase Amount")
ax1.set_title("Vendor Purchase Contribution (Pareto Analysis)")
ax1.tick_params(axis='x', rotation=90)
ax1.grid(False)

# cumulative line
ax2 = ax1.twinx()

ax2.plot(
    top_vendor['vendor_name'],
    top_vendor['cummulative_contribution'],
    color="red",
    marker="o"
)

ax2.set_ylabel("Cumulative Contribution %")
ax2.set_ylim(0,100)
ax2.grid(False)

# 80% line
ax2.axhline(80, color="black", linestyle="--")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### vendor procurement dependency (pareto analysis)
#
# 1. the chart shows that top 10 vendors contribute a large share of total purchase value.
# 2. this highlights potential dependency risk, suggesting the need of diversification.

# %% [markdown]
# ### Q. How much of total procurement is dependent on the top vendors ?

# %%
print(f'Total purchase contribution of top 10 vendors: {top_vendor['purchase_contribution'].sum()}%')
print(f'Total sales contribution of top 10 vendors: {vendor_performance["sales_contribution"].sum()}%')
# Out:
# Total purchase contribution of top 10 vendors: 65.34%
# Total sales contribution of top 10 vendors: 65.02%

# %%
import matplotlib.pyplot as plt

# Top vendors already computed
vendors = list(top_vendor['vendor_name'].values)
purchase_contributions = list(top_vendor['purchase_contribution'].values)

# calculate remaining contribution
total_contribution = sum(purchase_contributions)
remaining_contribution = 100 - total_contribution

# append Others
vendors.append("Other Vendors")
purchase_contributions.append(remaining_contribution)

colors = sns.color_palette("crest", len(purchase_contributions))

# donut chart
fig, ax = plt.subplots(figsize=(8,8))

wedges, texts, autotexts = ax.pie(
    purchase_contributions,
    labels=vendors,
    autopct='%1.2f%%',
    startangle=140,
    pctdistance=0.85,
    colors=colors,
    textprops={'fontsize':9, 'fontweight':'bold'}
)

# donut hole
centre_circle = plt.Circle((0,0),0.70,fc='white')
fig.gca().add_artist(centre_circle)

# center text
plt.text(
    0,0,
    f"Top 10 Total\n{total_contribution:.2f}%",
    fontsize=14,
    fontweight='bold',
    ha='center',
    va='center'
)

plt.title("Top 10 Vendors Purchase Contribution",fontweight='bold',fontsize=14)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Q. Does purchasing in bulk reduce the unit price and what is the optimal purchase volume for cost saving ?

# %%
# create unit price
df['unit_price'] = df['total_purchase_amount'] / df['total_purchase_qty']

# categorize order size
df['order_size'] = pd.qcut(
    df['total_purchase_qty'],
    q=3,
    labels=['Small','Medium','Large']
)

# analyze average unit price
df.groupby('order_size')['unit_price'].mean()
# Out:
# order_size
# Small     43.776954
# Medium    17.894005
# Large     11.308807
# Name: unit_price, dtype: float64

# %% [markdown]
# ### impact of bulk purchasing on unit price
#
# 1. results shows that unit price decreases as order size increases, indicating a clear bulk purchasing advantage.
# 2. this suggests that large purchase volumes can help reduce procurement costs.

# %% [markdown]
# ### Q. Which vendors have low inventory turnover, indicating excess stock and slow-moving products ?

# %%
# low sell_through_rate(slr) vendors
low_slr_vendor = df[(df['sell_through_rate'] < 1) & 
                    (df['sell_through_rate'] > 0)
 ].groupby('vendor_name')[['sell_through_rate']].mean().sort_values(by='sell_through_rate').head(10)
low_slr_vendor
# Out:
#                             sell_through_rate
# vendor_name
# TREASURY WINE ESTATES                    0.28
# SOUTHERN WINE & SPIRITS NE               0.33
# ULTRA BEVERAGE COMPANY LLP               0.57
# SOUTHERN GLAZERS W&S OF NE               0.60
# VINILANDIA USA                           0.68
# MARTIGNETTI COMPANIES                    0.70
# M S WALKER INC                           0.88

# %%
import numpy as np

vendor_slr = (
    df.groupby('vendor_name')
      .agg(
          total_sales=('total_sales_qty','sum'),
          total_purchase=('total_purchase_qty','sum')
      )
)

# avoid divide-by-zero
vendor_slr['sell_through_rate'] = np.where(
    vendor_slr['total_purchase'] > 0,
    vendor_slr['total_sales'] / vendor_slr['total_purchase'],
    np.nan
)

# inventory risk
vendor_slr['unsold_inventory'] = (
    vendor_slr['total_purchase'] - vendor_slr['total_sales']
)

# optional: remove tiny purchases
vendor_slr = vendor_slr[vendor_slr['total_purchase'] > 50]

# lowest performers
low_slr_vendor = (
    vendor_slr
    .sort_values('sell_through_rate')
    .head(10)
)

low_slr_vendor
# Out:
#                                total_sales  total_purchase  sell_through_rate  \
# vendor_name
# IRA GOLDMAN AND WILLIAMS, LLP         42.0             328           0.128049
# HIGHLAND WINE MERCHANTS LLC           82.0             372           0.220430
# UNCORKED                              61.0             243           0.251029
# VINEYARD BRANDS LLC                  104.0             371           0.280323
# LOYAL DOG WINERY                      74.0             240           0.308333
# BLACK COVE BEVERAGES                 313.0             919           0.340588
# GILMANTON WINERY & VINEYARD          240.0             516           0.465116
# APPOLO VINEYARDS LLC                 108.0             230           0.469565
# STARK BREWING COMPANY                846.0            1212           0.698020
# Circa Wines                         2443.0            3320           0.735843
#
#                                unsold_inventory
# vendor_name
# IRA GOLDMAN AND WILLIAMS, LLP             286.0
# HIGHLAND WINE MERCHANTS LLC               290.0
# UNCORKED                                  182.0
# VINEYARD BRANDS LLC                       267.0
# LOYAL DOG WINERY                          166.0
# BLACK COVE BEVERAGES                      606.0
# GILMANTON WINERY & VINEYARD               276.0
# APPOLO VINEYARDS LLC                      122.0
# STARK BREWING COMPANY                     366.0
# Circa Wines                               877.0

# %%
vendor_stock = (
    df.groupby('vendor_name')
      .agg(
          total_purchase=('total_purchase_qty','sum'),
          total_sales=('total_sales_qty','sum')
      )
)

# dead stock calculation
vendor_stock['dead_stock_qty'] = (
    vendor_stock['total_purchase'] -
    vendor_stock['total_sales']
)

vendor_stock['dead_stock_ratio'] = (
    vendor_stock['dead_stock_qty'] /
    vendor_stock['total_purchase']
)

# 🔴 apply purchase constraint
vendor_stock = vendor_stock[
    vendor_stock['total_purchase'] > 1000
]

# worst vendors
dead_stock_vendor = (
    vendor_stock
    .sort_values('dead_stock_ratio', ascending=False)
    .head(10)
)


dead_stock_vendor.round(2)
# Out:
#                             total_purchase  total_sales  dead_stock_qty  \
# vendor_name
# STARK BREWING COMPANY                 1212        846.0           366.0
# Circa Wines                           3320       2443.0           877.0
# Dunn Wine Brokers                     5448       4063.0          1385.0
# TAMWORTH DISTILLING                   1990       1488.0           502.0
# THE IMPORTED GRAPE LLC                2280       1719.0           561.0
# SWEETWATER FARM                       1629       1237.0           392.0
# SOUTHERN GLAZERS W&S OF NE            4198       3288.0           910.0
# TALL SHIP DISTILLERY LLC              2236       1786.0           450.0
# PARK STREET IMPORTS LLC               4349       3483.0           866.0
# DJINN SPIRITS LLC                     2637       2177.0           460.0
#
#                             dead_stock_ratio
# vendor_name
# STARK BREWING COMPANY                   0.30
# Circa Wines                             0.26
# Dunn Wine Brokers                       0.25
# TAMWORTH DISTILLING                     0.25
# THE IMPORTED GRAPE LLC                  0.25
# SWEETWATER FARM                         0.24
# SOUTHERN GLAZERS W&S OF NE              0.22
# TALL SHIP DISTILLERY LLC                0.20
# PARK STREET IMPORTS LLC                 0.20
# DJINN SPIRITS LLC                       0.17

# %%
dead_stock_vendor.sort_values('dead_stock_ratio').plot.barh(
    y='dead_stock_ratio',
    figsize=(8,5),
    legend=False
)
# Out:
# <Axes: ylabel='vendor_name'>

# %% [markdown]
# ### Q. How much capital is locked in unsold inventory per vendor and which vendors contributed the most to it ?

# %%
df['unsold_inventory'] = (df['total_purchase_qty'] - df['total_sales_qty']) * df['avg_purchase_price']
total_capital_at_risk = df['unsold_inventory'].sum()
print(f"Total Capital at Risk due to Unsold Inventory: ${total_capital_at_risk:,.2f}")
# Out:
# Total Capital at Risk due to Unsold Inventory: $8,750,806.76

# %%
ivnentory_risk = df.groupby('vendor_name')[['unsold_inventory']].sum().sort_values(by='unsold_inventory', ascending=False).head(10)
ivnentory_risk
# Out:
#                             unsold_inventory
# vendor_name
# DIAGEO NORTH AMERICA INC           981589.89
# MARTIGNETTI COMPANIES              928987.31
# JIM BEAM BRANDS COMPANY            857795.51
# ULTRA BEVERAGE COMPANY LLP         780266.12
# PERFECTA WINES                     571806.73
# PERNOD RICARD USA                  554740.67
# M S WALKER INC                     470108.40
# WILLIAM GRANT & SONS INC           436492.34
# E & J GALLO WINERY                 315202.46
# BROWN-FORMAN CORP                  284906.60

# %%
ivnentory_risk.plot.barh(
    figsize=(8,5),
    legend=False
)
# Out:
# <Axes: ylabel='vendor_name'>

# %% [markdown]
# ### Q. What is the distribution of vendors across strategic, risk, growth, and underperforming segments?

# %%
import plotly.express as px
import plotly.io as pio

pio.renderers.default = "vscode"

# vendor aggregation
vendor_perf = (
    df.groupby('vendor_name')
      .agg(
          total_sales=('total_sales_amount','sum'),
          avg_profit_margin=('profit_margin','mean')
      )
      .reset_index()
)

# thresholds
sales_threshold = vendor_perf['total_sales'].median()
margin_threshold = vendor_perf['avg_profit_margin'].median()

# classify vendors
def classify(row):
    if row['total_sales'] >= sales_threshold and row['avg_profit_margin'] >= margin_threshold:
        return "Strategic Vendors"
    elif row['total_sales'] >= sales_threshold and row['avg_profit_margin'] < margin_threshold:
        return "Margin Risk"
    elif row['total_sales'] < sales_threshold and row['avg_profit_margin'] >= margin_threshold:
        return "Growth Opportunity"
    else:
        return "Underperforming"

vendor_perf["vendor_group"] = vendor_perf.apply(classify, axis=1)

vendor_perf["size_scaled"] = np.log1p(vendor_perf["total_sales"])
# interactive scatter
fig = px.scatter(
    vendor_perf,
    x="total_sales",
    y="avg_profit_margin",
    color="vendor_group",
    hover_name="vendor_name",
    size="size_scaled",
    size_max=25,
    color_discrete_map={
        "Strategic Vendors":"green",
        "Margin Risk":"orange",
        "Growth Opportunity":"blue",
        "Underperforming":"red"
    },
    title="Vendor Risk Matrix",
    labels={
        "total_sales":"Total Sales",
        "avg_profit_margin":"Average Profit Margin"
    }
)

# quadrant lines
fig.add_vline(x=sales_threshold, line_dash="dash", line_color="black")
fig.add_hline(y=margin_threshold, line_dash="dash", line_color="black")


# improve layout
fig.update_layout(
    width=1100,
    height=650,
    template="plotly_white"
)

# log scale helps when sales are skewed
fig.update_xaxes(type="log")

fig.show()

# %%
vendor_group_count = (
    vendor_perf.groupby("vendor_group")["vendor_name"]
               .count()
               .reset_index(name="vendor_count")
)
vendor_group_count
# Out:
#          vendor_group  vendor_count
# 0  Growth Opportunity            26
# 1         Margin Risk            26
# 2   Strategic Vendors            34
# 3     Underperforming            33

# %% [markdown]
# ### Q. What is the average profit margin for top 25% sales vendors vs bottom 25% sales vendors? Are the differences statistically significant?

# %%
import numpy as np
from scipy import stats
df = df[df['profit_margin'] > 0]  # filter out zero sales to avoid skewing

# thresholds
top_threshold = df["total_sales_amount"].quantile(0.75)
low_threshold = df["total_sales_amount"].quantile(0.25)

# groups
top_vendors = df[df["total_sales_amount"] >= top_threshold]["profit_margin"].dropna()
low_vendors = df[df["total_sales_amount"] <= low_threshold]["profit_margin"].dropna()

# CI function
def confidence_interval(data, confidence=0.95):
    
    data = np.array(data)
    
    mean_val = np.mean(data)
    
    # standard error
    std_err = np.std(data, ddof=1) / np.sqrt(len(data))
    
    # t critical value
    t_critical = stats.t.ppf((1 + confidence) / 2, df=len(data) - 1)
    
    # margin of error
    margin_of_error = t_critical * std_err
    
    lower = mean_val - margin_of_error
    upper = mean_val + margin_of_error
    
    return mean_val, lower, upper
# compute CI
top_ci = confidence_interval(top_vendors)
low_ci = confidence_interval(low_vendors)

# %%
# compute CI
top_mean, top_lower, top_upper = confidence_interval(top_vendors)
low_mean, low_lower, low_upper = confidence_interval(low_vendors)

print(f"Top Vendors 95% CI: ({top_lower:.2f}, {top_upper:.2f}), Mean: {top_mean:.2f}")
print(f"Low Vendors 95% CI: ({low_lower:.2f}, {low_upper:.2f}), Mean: {low_mean:.2f}")

plt.figure(figsize=(10,6))

# Top vendors distribution
sns.histplot(
    top_vendors,
    kde=True,
    color="steelblue",
    bins=30,
    alpha=0.6,
    label="Top Vendors"
)

# Low vendors distribution
sns.histplot(
    low_vendors,
    kde=True,
    color="red",
    bins=30,
    alpha=0.6,
    label="Low Vendors"
)

# Top CI lines
plt.axvline(top_mean, color="blue", linestyle="-", linewidth=2)
plt.axvline(top_lower, color="blue", linestyle="--")
plt.axvline(top_upper, color="blue", linestyle="--")

# Low CI lines
plt.axvline(low_mean, color="red", linestyle="-", linewidth=2)
plt.axvline(low_lower, color="red", linestyle="--")
plt.axvline(low_upper, color="red", linestyle="--")

plt.title("Profit Margin Distribution with 95% Confidence Intervals")
plt.xlabel("Profit Margin")
plt.ylabel("Frequency")
plt.legend()
plt.show()
# Out:
# Top Vendors 95% CI: (30.74, 31.61), Mean: 31.18
# Low Vendors 95% CI: (40.50, 42.64), Mean: 41.57

# %% [markdown]
# # Test the profit margin difference between th vendor groups
#
# To test profit margin differences between vendor groups, use ANOVA because you have more than two groups:
#
# Groups:
#
#     Strategic Vendors
#
#     Margin Risk
#
#     Growth Opportunity
#
#     Underperforming
#
#     Define Hypothesis
#
# H0: Mean profit margin is equal across all vendor groups
#
# H1: At least one vendor group has a different mean profit margin

# %%
from scipy.stats import f_oneway

strategic = vendor_perf[vendor_perf["vendor_group"]=="Strategic Vendors"]["avg_profit_margin"]
margin_risk = vendor_perf[vendor_perf["vendor_group"]=="Margin Risk"]["avg_profit_margin"]
growth = vendor_perf[vendor_perf["vendor_group"]=="Growth Opportunity"]["avg_profit_margin"]
underperform = vendor_perf[vendor_perf["vendor_group"]=="Underperforming"]["avg_profit_margin"]

anova_result = f_oneway(strategic, margin_risk, growth, underperform)

print("F-statistic:", anova_result.statistic)
print("p-value:", anova_result.pvalue)
# Out:
# F-statistic: 49.65472671055262
# p-value: 1.1614485732274548e-20

# %% [markdown]
# ANOVA results indicate a significant difference in profit margins across vendor groups
# (F = 49.65, p < 0.001).
#
# Strategic vendors generate substantially higher margins,
# while underperforming vendors show significantly lower profitability.
#
# This confirms that the vendor segmentation reflects real differences in vendor performance.

# %% [markdown]
# # Test sales vs margin correlation
#
# H0: Sales and profit margin are not correlated
#
# H1: Sales and profit margin are correlated

# %%
from scipy.stats import pearsonr

corr, p_value = pearsonr(
    vendor_perf["total_sales"],
    vendor_perf["avg_profit_margin"]
)

print("Correlation:", corr)
print("p-value:", p_value)
# Out:
# Correlation: -0.016980187789324443
# p-value: 0.8545704766659837

# %% [markdown]
# Correlation analysis between vendor sales and profit margin shows no
# significant relationship (r = -0.017, p = 0.855), indicating that higher
# sales volumes do not systematically lead to lower or higher margins.
#
# Vendor profitability appears to be influenced by factors other than sales volume.

# %% [markdown]
# # Test strategic vendors generate significantly higher profit margins than underperforming vendors?
#
# H0: Mean profit margin of Strategic Vendors = Underperforming Vendors
#
# H1: Strategic Vendors have higher profit margins

# %%
from scipy.stats import ttest_ind

strategic = vendor_perf[
    vendor_perf["vendor_group"]=="Strategic Vendors"
]["avg_profit_margin"]

underperform = vendor_perf[
    vendor_perf["vendor_group"]=="Underperforming"
]["avg_profit_margin"]

t_stat, p_value = ttest_ind(strategic, underperform, equal_var=False)

print("t-statistic:", t_stat)
print("p-value:", p_value)
# Out:
# t-statistic: 10.423106109243324
# p-value: 9.81779424563267e-15

# %% [markdown]
# t-test shows a statistically significant difference in profit margins
# between Strategic Vendors and Underperforming Vendors (t = 10.42, p < 0.001).
#
# Strategic vendors consistently generate higher profitability,
# validating the segmentation derived from the Vendor Risk Matrix.

# %% [markdown]
# # Quantitative business impact analysis
#
# analyze quantitative business impact after identifying target brands and vendors to prioritize for improvement.
#
# This includes estimating potential revenue uplift from promoting high-margin, low-sales brands and cost savings from addressing inventory risks with underperforming vendors.

# %%
df = pd.read_sql("select * from gold.vendor_performance", engine)

# %%
vendor_perf = (
    df.groupby('vendor_name')
      .agg(
          total_sales=('total_sales_amount','sum'),
          avg_profit_margin=('profit_margin','mean')
      )
      .reset_index()
)

# thresholds
sales_threshold = vendor_perf['total_sales'].median()
margin_threshold = vendor_perf['avg_profit_margin'].median()

# classify vendors
def classify(row):
    if row['total_sales'] >= sales_threshold and row['avg_profit_margin'] >= margin_threshold:
        return "Strategic Vendors"
    elif row['total_sales'] >= sales_threshold and row['avg_profit_margin'] < margin_threshold:
        return "Margin Risk"
    elif row['total_sales'] < sales_threshold and row['avg_profit_margin'] >= margin_threshold:
        return "Growth Opportunity"
    else:
        return "Underperforming"

vendor_perf["vendor_group"] = vendor_perf.apply(classify, axis=1)

df = df.merge(
    vendor_perf[['vendor_name','vendor_group']],
    on='vendor_name',
    how='left'
)

# %%
import pandas as pd

# =========================
# 1. BASELINE METRICS
# =========================

df['unsold_inventory'] = (
    (df['total_purchase_qty'] - df['total_sales_qty']) *
    df['avg_purchase_price']
)

baseline_revenue = df["total_sales_amount"].sum()
baseline_profit = df["gross_profit"].sum()

baseline_margin = (
    baseline_profit / baseline_revenue
) * 100 if baseline_revenue > 0 else 0

baseline_inventory = df["unsold_inventory"].sum()


# =========================
# 2. DEFINE IMPROVEMENT SCENARIO
# =========================

improved_df = df.copy()

# remove underperforming vendors
improved_df = improved_df[
    improved_df["vendor_group"] != "Underperforming"
]

# increase strategic vendor sales
improved_df["total_sales_amount"] = improved_df["total_sales_amount"].astype(float)

improved_df.loc[
    improved_df["vendor_group"] == "Strategic Vendors",
    "total_sales_amount"
] *= 1.10


# reduce inventory from low sell-through vendors
improved_df["total_purchase_qty"] = improved_df["total_purchase_qty"].astype(float)

improved_df.loc[
    improved_df["sell_through_rate"] < 0.5,
    "total_purchase_qty"
] *= 0.7


# recalculate gross profit
improved_df["gross_profit"] = (
    improved_df["total_sales_amount"] -
    improved_df["total_purchase_amount"]
)

# recalculate margin
improved_df["profit_margin"] = (
    improved_df["gross_profit"] /
    improved_df["total_sales_amount"]
)


# recalc inventory
improved_df["unsold_inventory"] = (
    (improved_df["total_purchase_qty"] - improved_df["total_sales_qty"]) *
    improved_df["avg_purchase_price"]
)


# =========================
# 3. RECALCULATE METRICS
# =========================

after_revenue = improved_df["total_sales_amount"].sum()
after_profit = improved_df["gross_profit"].sum()

after_margin = (
    after_profit / after_revenue
) * 100 if after_revenue > 0 else 0

after_inventory = improved_df["unsold_inventory"].sum()


# =========================
# 4. IMPACT TABLE
# =========================

impact_df = pd.DataFrame({
    "Metric": ["Revenue","Profit","Margin","Inventory"],
    "Before": [baseline_revenue, baseline_profit, baseline_margin, baseline_inventory],
    "After": [after_revenue, after_profit, after_margin, after_inventory]
})


impact_df["Change"] = impact_df["After"] - impact_df["Before"]
impact_df["Change %"] = (impact_df["Change"] / impact_df["Before"]) * 100

display_impact_df = impact_df.copy()
# =========================
# 5. FORMAT OUTPUT
# =========================
display_impact_df[["Before","After","Change", "Change %"]] =  display_impact_df[["Before","After","Change", "Change %"]].astype(object)


# format revenue, profit, inventory rows
money_mask = display_impact_df["Metric"] != "Margin"

display_impact_df.loc[money_mask, ["Before","After","Change"]] = (
    display_impact_df.loc[money_mask, ["Before","After","Change"]]
    .apply(lambda x:x.map(lambda x: f"${x:,.2f}"))
)

# format margin rows
margin_mask = display_impact_df["Metric"] == "Margin"

display_impact_df.loc[margin_mask, "Before"] = display_impact_df.loc[margin_mask, "Before"].apply(lambda x: f"{x:.2f}%")
display_impact_df.loc[margin_mask, "After"] = display_impact_df.loc[margin_mask, "After"].apply(lambda x: f"{x:.2f}%")
display_impact_df.loc[margin_mask, "Change"] = display_impact_df.loc[margin_mask, "Change"].apply(lambda x: f"{x:.2f} pp")

# change %
display_impact_df["Change %"] = display_impact_df["Change %"].apply(lambda x: f"{x:.2f}%")


display(display_impact_df)
# Out:
#       Metric           Before            After          Change Change %
# 0    Revenue  $451,620,183.69  $475,320,323.88  $23,700,140.19    5.25%
# 1     Profit  $130,001,601.81  $154,615,794.90  $24,614,193.09   18.93%
# 2     Margin           28.79%           32.53%         3.74 pp   13.00%
# 3  Inventory    $8,750,806.76    $8,394,194.17    $-356,612.59   -4.08%
